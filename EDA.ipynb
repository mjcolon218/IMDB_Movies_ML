# %% [markdown]
# ## Overview of Features.
# #### Unnamed: 0: An index column.
# #### Rank: The rank of the movie.
# #### Title: The title of the movie.
# #### Genre: The genre(s) of the movie.
# #### Director: The director of the movie.
# #### Actors: The main actors in the movie.
# #### Year: The year of release.
# #### Runtime (Minutes): The duration of the movie in minutes.
# #### Rating: The IMDb rating of the movie.
# #### Votes: The number of votes the movie received on IMDb.
# #### Revenue (Millions): The revenue of the movie in millions.
# #### Metascore: The metascore of the movie.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Load the dataset
file_path = 'data/IMDB-Movie-Data.csv'
movie_data = pd.read_csv(file_path)

# Display the first few rows of the dataset
movie_data.head()
# Out:
#    Unnamed: 0  Rank                    Title                     Genre  \
# 0           0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1           1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2           2     3                    Split           Horror,Thriller
# 3           3     4                     Sing   Animation,Comedy,Family
# 4           4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                Director                                             Actors  \
# 0            James Gunn  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# 1          Ridley Scott  Noomi Rapace, Logan Marshall-Green, Michael Fa...
# 2    M. Night Shyamalan  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# 3  Christophe Lourdelet  Matthew McConaughey,Reese Witherspoon, Seth Ma...
# 4            David Ayer  Will Smith, Jared Leto, Margot Robbie, Viola D...
#
#    Year  Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# ...

# %%
movie_data.columns
# Out:
# Index(['Unnamed: 0', 'Rank', 'Title', 'Genre', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
movie_data.Year.unique()
# Out:
# array([2014, 2012, 2016, 2011, 2015, 2008, 2006, 2007, 2009, 2010, 2013],
#       dtype=int64)

# %%
movie_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 838 entries, 0 to 837
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          838 non-null    int64
#  1   Rank                838 non-null    int64
#  2   Title               838 non-null    object
#  3   Genre               838 non-null    object
#  4   Director            838 non-null    object
#  5   Actors              838 non-null    object
#  6   Year                838 non-null    int64
#  7   Runtime (Minutes)   838 non-null    int64
#  8   Rating              838 non-null    float64
#  9   Votes               838 non-null    int64
#  10  Revenue (Millions)  838 non-null    float64
#  11  Metascore           838 non-null    float64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 78.7+ KB

# %%
# Basic statistics
basic_stats = movie_data.describe()
basic_stats
# Out:
#        Unnamed: 0         Rank        Year  Runtime (Minutes)      Rating  \
# count  838.000000   838.000000   838.00000         838.000000  838.000000
# mean   484.247017   485.247017  2012.50716         114.638425    6.814320
# std    286.572065   286.572065     3.17236          18.470922    0.877754
# min      0.000000     1.000000  2006.00000          66.000000    1.900000
# 25%    237.250000   238.250000  2010.00000         101.000000    6.300000
# 50%    474.500000   475.500000  2013.00000         112.000000    6.900000
# 75%    728.750000   729.750000  2015.00000         124.000000    7.500000
# max    999.000000  1000.000000  2016.00000         187.000000    9.000000
#
#               Votes  Revenue (Millions)   Metascore
# count  8.380000e+02          838.000000  838.000000
# mean   1.932303e+05           84.564558   59.575179
# std    1.930990e+05          104.520227   16.952416
# min    1.780000e+02            0.000000   11.000000
# ...

# %% [markdown]
# # Basic Statistics
# ##### Count: There are 838 movies in the dataset.
# ##### Year: The movies range from 2006 to 2016.
# ##### Runtime: The average runtime is approximately 115 minutes.
# ##### Rating: The average IMDb rating is around 6.8, with a minimum of 1.9 and a maximum of 9.0.
# ##### Votes: There's a wide range in the number of votes, indicating varying levels of popularity.
# ##### Revenue: The average revenue is about 84.56 million dollars.
# ##### Metascore: The average metascore is around 59.6.

# %%
# Setting up the aesthetics for the plots
sns.set(style="whitegrid")

# Creating visualizations
fig, axes = plt.subplots(3, 1, figsize=(10, 15))

# Distribution of movies over the years
sns.histplot(movie_data['Year'], bins=range(movie_data['Year'].min(), movie_data['Year'].max() + 1), ax=axes[0], kde=False)
axes[0].set_title('Distribution of Movies Over Years')
axes[0].set_xlabel('Year')
axes[0].set_ylabel('Number of Movies')

# Distribution of movie ratings
sns.histplot(movie_data['Rating'], ax=axes[1], kde=True)
axes[1].set_title('Distribution of Movie Ratings')
axes[1].set_xlabel('Rating')
axes[1].set_ylabel('Frequency')
# Distribution of movie revenues
sns.histplot(movie_data['Revenue (Millions)'].dropna(), ax=axes[2], kde=True)
axes[2].set_title('Distribution of Movie Revenues')
axes[2].set_xlabel('Revenue (Millions)')
axes[2].set_ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Distribution of Movies Over Years (Histogram):
#
# Showed an increasing trend in the number of movies over the years, peaking around 2016.
# * Inference: Indicates a growth in movie production or improved data collection in recent years.
# #### Distribution of Movie Ratings (Histogram):
#
# Revealed a somewhat normal but slightly left-skewed distribution, with most ratings between 6 and 8.
# * Inference: Suggests a general trend of average to good quality movies in the dataset.

# %% [markdown]
# # Visualizations
# ##### Distribution of Movies Over Years:
# * The histogram shows a roughly increasing trend in the number of movies over the years, with a peak around 2016. This indicates a growth in movie production over the analyzed period.
# * Distribution of Movie Ratings:
#
# * The distribution of movie ratings is somewhat normal but slightly left-skewed. Most movies have ratings between 6 and 8. Very few movies have ratings below 4 or above 8.
# Distribution of Movie Revenues:
#
# * The revenue distribution is right-skewed, indicating that a large number of movies earn relatively low revenues, while a few movies earn significantly high revenues.

# %% [markdown]
# # Insights and Observations
# * Popularity and Quality: The wide range of votes and ratings suggests a diverse mix of popularity and perceived quality among the movies.
# * Revenue Distribution: The skewness in the revenue distribution might indicate that only a small number of movies are highly successful commercially.
# * Time Trend: The increasing number of movies over the years could be reflective of the growing film industry or possibly increased data collection in recent years.

# %%
# 1. Bar Plot: Count of movies in each Primary Genre
plt.figure(figsize=(12, 6))
sns.countplot(x='Genre', data=movie_data, order=movie_data['Genre'].value_counts().index)
plt.title('Count of Movies in Each Primary Genre')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# 2. Count Plot: Number of movies released each year
plt.figure(figsize=(10, 6))
sns.countplot(x='Year', data=movie_data)
plt.title('Number of Movies Released Each Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# 3. Box Plot: Distribution of Rating across Directors (selecting top directors)
top_directors = movie_data['Director'].value_counts().nlargest(10).index
filtered_data = movie_data[movie_data['Director'].isin(top_directors)]
plt.figure(figsize=(12, 6))
sns.boxplot(x='Director', y='Rating', data=filtered_data)
plt.title('Distribution of Ratings Across Top Directors')
plt.xlabel('Director')
plt.ylabel('Rating')
plt.xticks(rotation=45)
plt.show()

# 4. Strip Plot: Distribution of Revenue across Primary Genres
plt.figure(figsize=(12, 6))
sns.stripplot(x='Genre', y='Revenue (Millions)', data=movie_data)
plt.title('Distribution of Revenue Across Primary Genres')
plt.xlabel('Primary Genre')
plt.ylabel('Revenue (Millions)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Modified the Genres Columns so we can get some meaning out of it.

# %%
# 1. Bar Plot: Count of movies in each Primary Genre
plt.figure(figsize=(12, 6))
sns.countplot(x='Broad Genre', data=movie_data, order=movie_data['Broad Genre'].value_counts().index)
plt.title('Count of Movies in Each Primary Genre')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# 2. Count Plot: Number of movies released each year
plt.figure(figsize=(10, 6))
sns.countplot(x='Year', data=movie_data)
plt.title('Number of Movies Released Each Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# 3. Box Plot: Distribution of Rating across Directors (selecting top directors)
top_directors = movie_data['Director'].value_counts().nlargest(10).index
filtered_data = movie_data[movie_data['Director'].isin(top_directors)]
plt.figure(figsize=(12, 6))
sns.boxplot(x='Director', y='Rating', data=filtered_data)
plt.title('Distribution of Ratings Across Top Directors')
plt.xlabel('Director')
plt.ylabel('Rating')
plt.xticks(rotation=45)
plt.show()

# 4. Strip Plot: Distribution of Revenue across Primary Genres
plt.figure(figsize=(12, 6))
sns.stripplot(x='Broad Genre', y='Revenue (Millions)', data=movie_data)
plt.title('Distribution of Revenue Across Primary Genres')
plt.xlabel('Primary Genre')
plt.ylabel('Revenue (Millions)')
plt.xticks(rotation=45)
plt.show()

# %%
# Heatmap: Correlation between numerical features
correlation_matrix = movie_data[['Rating', 'Revenue (Millions)', 'Votes', 'Runtime (Minutes)']].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# Pair Plot: Pairwise relationships with Year as hue
pair_plot_data = movie_data[['Rating', 'Revenue (Millions)', 'Votes', 'Year']]
sns.pairplot(pair_plot_data, hue='Year', palette='viridis')
plt.suptitle('Pair Plot of Rating, Revenue, and Votes with Year as Hue', y=1.02)
plt.show()

# Stacked Bar Plot: Proportion of total revenue by Primary Genre over years
pivot_data = movie_data.pivot_table(values='Revenue (Millions)', index='Year', columns='Broad Genre', aggfunc='sum', fill_value=0)
pivot_data_percentage = pivot_data.div(pivot_data.sum(axis=1), axis=0)
pivot_data_percentage.plot(kind='bar', stacked=True, colormap='tab20', figsize=(10, 6))
plt.title('Proportion of Total Revenue by Broad Genre Over Years')
plt.ylabel('Percentage of Total Revenue')
plt.xlabel('Year')
plt.legend(title='Genre', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# Line Plot: Trend of average Rating and Metascore over the years
average_ratings = movie_data.groupby('Year')['Rating'].mean()
average_metascores = movie_data.groupby('Year')['Metascore'].mean()
plt.figure(figsize=(10, 6))
plt.plot(average_ratings, label='Average Rating')
plt.plot(average_metascores, label='Average Metascore')
plt.title('Trend of Average Rating and Metascore Over Years')
plt.xlabel('Year')
plt.ylabel('Average Score')
plt.legend()
plt.show()
# Out:
# c:\Users\mjcol\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Extracting all genres and their frequencies
all_genres = movie_data['Genre'].str.split(',', expand=True).stack()
genre_counts = all_genres.value_counts()

genre_counts
# Out:
# Drama        419
# Action       277
# Comedy       250
# Adventure    244
# Thriller     148
# Crime        126
# Romance      120
# Sci-Fi       107
# Fantasy       92
# Horror        87
# Mystery       86
# Biography     67
# Family        48
# Animation     45
# History       25
# Music         15
# Sport         15
# War           10
# Musical        5
# Western        4
# Name: count, dtype: int64

# %% [markdown]
# ## Grouping into Broader Categories
# ### Drama/Thriller/Crime: Combining Drama, Thriller, and Crime.
# ### Comedy/Romance: Merging Comedy and Romance.
# ### Action/Adventure/Sci-Fi/Fantasy: Grouping Action, Adventure, Sci-Fi, and Fantasy.
# ### Family/Animation: Combining Family and Animation.
# ### Horror/Mystery: Merging Horror and Mystery.
# ### Biography/History/Music/Sport/War: These genres are often associated with real-life stories or historical events.
# ### Other: A category for less frequent genres like Musical and Western, or any genre that does not fit into the above groups.

# %%
# Function to categorize movies into broader genre groups
def categorize_genre(genres):
    # Define genre groups
    groups = {
        "Drama/Thriller/Crime": ['Drama', 'Thriller', 'Crime'],
        "Comedy/Romance": ['Comedy', 'Romance'],
        "Action/Adventure/Sci-Fi/Fantasy": ['Action', 'Adventure', 'Sci-Fi', 'Fantasy'],
        "Family/Animation": ['Family', 'Animation'],
        "Horror/Mystery": ['Horror', 'Mystery'],
        "Biography/History/Music/Sport/War": ['Biography', 'History', 'Music', 'Sport', 'War']
    }
    
    for group, genres_list in groups.items():
        if any(genre in genres for genre in genres_list):
            return group
    return "Other"

# Apply the function to the dataset
movie_data['Broad Genre'] = movie_data['Genre'].apply(lambda x: categorize_genre(x.split(',')))

# Displaying the new categorization
movie_data[['Title', 'Genre', 'Broad Genre']].head()
# Out:
#                      Title                     Genre  \
# 0  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1               Prometheus  Adventure,Mystery,Sci-Fi
# 2                    Split           Horror,Thriller
# 3                     Sing   Animation,Comedy,Family
# 4            Suicide Squad  Action,Adventure,Fantasy
#
#                        Broad Genre
# 0  Action/Adventure/Sci-Fi/Fantasy
# 1  Action/Adventure/Sci-Fi/Fantasy
# 2             Drama/Thriller/Crime
# 3                   Comedy/Romance
# 4  Action/Adventure/Sci-Fi/Fantasy

# %%
movie_data.head()
# Out:
#    Unnamed: 0  Rank                    Title                     Genre  \
# 0           0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1           1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2           2     3                    Split           Horror,Thriller
# 3           3     4                     Sing   Animation,Comedy,Family
# 4           4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                Director                                             Actors  \
# 0            James Gunn  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# 1          Ridley Scott  Noomi Rapace, Logan Marshall-Green, Michael Fa...
# 2    M. Night Shyamalan  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# 3  Christophe Lourdelet  Matthew McConaughey,Reese Witherspoon, Seth Ma...
# 4            David Ayer  Will Smith, Jared Leto, Margot Robbie, Viola D...
#
#    Year  Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore  \
# ...

# %%
# Extracting all actors and their frequencies
all_actors = movie_data['Actors'].str.split(',', expand=True).stack()
actor_counts = all_actors.value_counts()

actor_counts
# Out:
# Mark Wahlberg           11
# Christian Bale          11
# Jake Gyllenhaal          9
#  Woody Harrelson         9
#  Rose Byrne              9
#                         ..
#  Oona Laurence           1
#  Jonny Brugh             1
# Cori Gonzalez-Macuer     1
#  Taika Waititi           1
# Cheryl Hines             1
# Name: count, Length: 1986, dtype: int64

# %%
# Displaying the top 20 actors
top_actors = actor_counts.head(20)

# Visualizing the top actors
plt.figure(figsize=(12, 8))
sns.barplot(x=top_actors.values, y=top_actors.index)
plt.title('Top 20 Actors by Number of Appearances in Movies')
plt.xlabel('Number of Appearances')
plt.ylabel('Actor')
plt.show()

# %%
# Visualization 1: Bar Plot - Count of movies in each broad genre category
plt.figure(figsize=(10, 6))
sns.countplot(y='Broad Genre', data=movie_data, order=movie_data['Broad Genre'].value_counts().index)
plt.title('Count of Movies in Each Broad Genre Category')
plt.xlabel('Count')
plt.ylabel('Broad Genre')
plt.show()

# Visualization 2: Box Plot - Distribution of Rating across broad genre categories
plt.figure(figsize=(10, 6))
sns.boxplot(x='Rating', y='Broad Genre', data=movie_data)
plt.title('Distribution of Ratings Across Broad Genre Categories')
plt.xlabel('Rating')
plt.ylabel('Broad Genre')
plt.show()

# Visualization 3: Violin Plot - Distribution of Revenue across broad genre categories
plt.figure(figsize=(10, 6))
sns.violinplot(x='Revenue (Millions)', y='Broad Genre', data=movie_data)
plt.title('Distribution of Revenue Across Broad Genre Categories')
plt.xlabel('Revenue (Millions)')
plt.ylabel('Broad Genre')
plt.show()

# Visualization 4: Stacked Bar Plot - Proportion of movies in each broad genre category across years
plt.figure(figsize=(12, 8))
year_genre_proportion.plot(kind='bar', stacked=True, colormap='tab20')
plt.title('Proportion of Movies in Each Broad Genre Category Across Years')
plt.ylabel('Proportion')
plt.xlabel('Year')
plt.legend(title='Broad Genre', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
from wordcloud import WordCloud

# Word Cloud: Visualization of the most frequent words in movie titles
all_titles = ' '.join(movie_data['Title'])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_titles)

# Displaying the Word Cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Movie Titles')
plt.show()

# Histogram: Distribution of Movie Runtime
plt.figure(figsize=(10, 6))
sns.histplot(movie_data['Runtime (Minutes)'], kde=True)
plt.title('Distribution of Movie Runtime')
plt.xlabel('Runtime (Minutes)')
plt.ylabel('Frequency')
plt.show()

# Pie Chart: Movie Distribution by Year
year_distribution = movie_data['Year'].value_counts()
plt.figure(figsize=(10, 6))
year_distribution.plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.title('Movie Distribution by Year')
plt.ylabel('')
plt.show()

# Scatter Plot with Hue for Genre: Rating vs Revenue
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Rating', y='Revenue (Millions)', hue='Broad Genre', data=movie_data)
plt.title('Rating vs Revenue with Broad Genre as Hue')
plt.xlabel('Rating')
plt.ylabel('Revenue (Millions)')
plt.show()

# %% [markdown]
# Distribution of Movie Runtime:
#
# Displays the distribution of runtime for movies in the dataset.
# Most movies seem to have a runtime around 100-120 minutes, indicating a standard movie length in the industry.
# Pie Chart of Movie Distribution by Year:
#
# Illustrates the proportion of movies released in each year.
# Provides a visual representation of the distribution of movie releases over the years, showing how production may have varied
# Scatter Plot with Broad Genre as Hue (Rating vs Revenue):
#
# Explores the relationship between movie ratings and revenue, with different genres represented by different colors.
# This plot helps to observe how genre influences the relationship between a movie's rating and its financial success. It appears that certain genres, like Action/Adventure/Sci-Fi/Fantasy, have a wide range of revenue regardless of the rating.

# %% [markdown]
# # Statistical Summary

# %% [markdown]
# * Distribution of Movies Over Years (Histogram):
#
# Showed an increasing trend in the number of movies over the years, peaking around 2016.
# Inference: Indicates a growth in movie production or improved data collection in recent years.
# * Distribution of Movie Ratings (Histogram):
#
# Revealed a somewhat normal but slightly left-skewed distribution, with most ratings between 6 and 8.
# Inference: Suggests a general trend of average to good quality movies in the dataset.
# * Distribution of Movie Revenues (Histogram):
#
# Displayed a right-skewed distribution, indicating many movies earn relatively low revenues while a few earn significantly high revenues.
# Inference: Highlights that high revenues are not common and are likely influenced by factors other than just quality.
# * Rating vs Revenue with Year as Hue (Scatter Plot):
#
# Illustrated no clear linear relationship between rating and revenue across different years.
# Inference: Implies that a movie's financial success is not directly correlated with its IMDb rating.
# * Metascore vs Revenue with Primary Genre as Hue (Scatter Plot):
#
# Showed no evident linear correlation between metascore and revenue across genres.
# Inference: Suggests that critical acclaim (metascore) doesn't necessarily translate into financial success.
# * 3D Chart: Rating, Revenue, and Votes:
#
# Explored the interplay between a movie's rating, revenue, and votes.
# Inference: Indicates a complex relationship between these factors; high revenue and popularity (votes) don't always correlate with high ratings.
# * Bar Plot (Count of Movies in Each Primary Genre):
#
# Indicated the prevalence of genres like Drama, Action, and Comedy.
# Inference: These genres are more common, possibly reflecting their popularity or commercial appeal.
# * Count Plot (Number of Movies Released Each Year):
#
# Showed a general increase in the number of movies over time.
# Inference: Reflects the growth of the movie industry or improved data collection.
# * Box Plot (Distribution of Ratings Across Top Directors):
#
# Highlighted the variation in ratings among movies by top directors.
# Inference: Some directors consistently produce higher-rated movies, while others have a broader range of ratings.
# * Strip Plot (Distribution of Revenue Across Primary Genres):
#
# Illustrated the wide range of revenue across genres.
# Inference: Suggests that genres like Action and Adventure often have higher revenue potential.
# * Word Cloud (Movie Titles):
# Highlighted the most common words in movie titles.
# Inference: Reflects popular themes or keywords in movie titles.
# * Histogram (Distribution of Movie Runtime):
# Most movies had a runtime around 100-120 minutes.
# Inference: Indicates a standard movie length prevalent in the industry.
# * Pie Chart (Movie Distribution by Year):
# Showed the proportion of movies released each year.
# Inference: Provides a visual representation of the distribution and trends in movie releases over the years.
# * Scatter Plot with Broad Genre as Hue (Rating vs Revenue):
# Explored how genre influences the relationship between rating and revenue.
# Inference: Indicates that genre plays a role in a movie's financial success relative to its rating.
